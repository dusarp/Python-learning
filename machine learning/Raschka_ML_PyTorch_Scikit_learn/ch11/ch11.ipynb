# %%
#Implementing a Multi-layer Artificial Neural Network from Scratch

# %%
#obtaining and preparing the MNIST dataset

# %%
from sklearn.datasets import fetch_openml

X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X.values
y = y.astype(int).values

print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
#normalize it to [-1,1]
X = ((X / 255.) - .5) * 2

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(10):
    img = X[y == i][0].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_4.png', dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(25):
    img = X[y == 7][i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
# plt.savefig('figures/11_5.png', dpi=300)
plt.show()

# %%
from sklearn.model_selection import train_test_split


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=10000, random_state=123, stratify=y)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_temp, y_temp, test_size=5000, random_state=123, stratify=y_temp)


# optional to free up some memory by deleting non-used arrays:
del X_temp, y_temp, X, y

# %%
#implementing a multi layer perceptron
import numpy as np

# %%
##########################
### MODEL
##########################

def sigmoid(z):
    return np.maximum(0, z)                                        
   # return 1. / (1. + np.exp(-z))
#replaced sigmoid with relu the sigmoid a neve

def int_to_onehot(y, num_labels):

    ary = np.zeros((y.shape[0], num_labels))
    for i, val in enumerate(y):
        ary[i, val] = 1

    return ary


class NeuralNetMLP:

    def __init__(self, num_features, num_hidden, num_classes, random_seed=123):
        super().__init__()
        
        self.num_classes = num_classes
        
        # hidden
        rng = np.random.RandomState(random_seed)
        
        self.weight_h = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden, num_features))
        self.bias_h = np.zeros(num_hidden)
        
        # output
        self.weight_out = rng.normal(
            loc=0.0, scale=0.1, size=(num_classes, num_hidden))
        self.bias_out = np.zeros(num_classes)
        
    def forward(self, x):
        # Hidden layer
        # input dim: [n_examples, n_features] dot [n_hidden, n_features].T
        # output dim: [n_examples, n_hidden]
        z_h = np.dot(x, self.weight_h.T) + self.bias_h
        a_h = sigmoid(z_h)

        # Output layer
        # input dim: [n_examples, n_hidden] dot [n_classes, n_hidden].T
        # output dim: [n_examples, n_classes]
        z_out = np.dot(a_h, self.weight_out.T) + self.bias_out
        a_out = sigmoid(z_out)
        return a_h, a_out

    def backward(self, x, a_h, a_out, y):  
    
        #########################
        ### Output layer weights
        #########################
        
        # onehot encoding
        y_onehot = int_to_onehot(y, self.num_classes)

        # Part 1: dLoss/dOutWeights
        ## = dLoss/dOutAct * dOutAct/dOutNet * dOutNet/dOutWeight
        ## where DeltaOut = dLoss/dOutAct * dOutAct/dOutNet
        ## for convenient re-use
        
        # input/output dim: [n_examples, n_classes]
        d_loss__d_a_out = 2.*(a_out - y_onehot) / y.shape[0]

        # input/output dim: [n_examples, n_classes]
        #d_a_out__d_z_out = a_out * (1. - a_out) # sigmoid derivative
        #d_a_out__d_z_out = return np.where(x > 0, 1, 0)

        # output dim: [n_examples, n_classes]
        delta_out = d_loss__d_a_out * d_a_out__d_z_out # "delta (rule) placeholder"

        # gradient for output weights
        
        # [n_examples, n_hidden]
        d_z_out__dw_out = a_h
        
        # input dim: [n_classes, n_examples] dot [n_examples, n_hidden]
        # output dim: [n_classes, n_hidden]
        d_loss__dw_out = np.dot(delta_out.T, d_z_out__dw_out)
        d_loss__db_out = np.sum(delta_out, axis=0)
        

        #################################        
        # Part 2: dLoss/dHiddenWeights
        ## = DeltaOut * dOutNet/dHiddenAct * dHiddenAct/dHiddenNet * dHiddenNet/dWeight
        
        # [n_classes, n_hidden]
        d_z_out__a_h = self.weight_out
        
        # output dim: [n_examples, n_hidden]
        d_loss__a_h = np.dot(delta_out, d_z_out__a_h)
        
        # [n_examples, n_hidden]
        d_a_h__d_z_h = a_h * (1. - a_h) # sigmoid derivative
        
        # [n_examples, n_features]
        d_z_h__d_w_h = x
        
        # output dim: [n_hidden, n_features]
        d_loss__d_w_h = np.dot((d_loss__a_h * d_a_h__d_z_h).T, d_z_h__d_w_h)
        d_loss__d_b_h = np.sum((d_loss__a_h * d_a_h__d_z_h), axis=0)

        return (d_loss__dw_out, d_loss__db_out, 
                d_loss__d_w_h, d_loss__d_b_h)

# %%
model = NeuralNetMLP(num_features=28*28,
                     num_hidden=50,
                     num_classes=10)

# %%
#defining data loaders
import numpy as np

num_epochs = 50
minibatch_size = 100


def minibatch_generator(X, y, minibatch_size):
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size 
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]
        
        yield X[batch_idx], y[batch_idx]

        
# iterate over training epochs
for i in range(num_epochs):

    # iterate over minibatches
    minibatch_gen = minibatch_generator(
        X_train, y_train, minibatch_size)
    
    for X_train_mini, y_train_mini in minibatch_gen:

        break
        
    break
    
print(X_train_mini.shape)
print(y_train_mini.shape)
# Out:
# (100, 784)
# (100,)

# %%
#Defining a function to compute the loss and accuracy
def mse_loss(targets, probas, num_labels=10):
    onehot_targets = int_to_onehot(targets, num_labels=num_labels)
    return np.mean((onehot_targets - probas)**2)


def accuracy(targets, predicted_labels):
    return np.mean(predicted_labels == targets) 


_, probas = model.forward(X_valid)
mse = mse_loss(y_valid, probas)

predicted_labels = np.argmax(probas, axis=1)
acc = accuracy(y_valid, predicted_labels)

print(f'Initial validation MSE: {mse:.1f}')
print(f'Initial validation accuracy: {acc*100:.1f}%')
# Out:
# Initial validation MSE: 0.3
# Initial validation accuracy: 9.4%

# %%
def compute_mse_and_acc(nnet, X, y, num_labels=10, minibatch_size=100):
    mse, correct_pred, num_examples = 0., 0, 0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)
        
    for i, (features, targets) in enumerate(minibatch_gen):

        _, probas = nnet.forward(features)
        predicted_labels = np.argmax(probas, axis=1)
        
        onehot_targets = int_to_onehot(targets, num_labels=num_labels)
        loss = np.mean((onehot_targets - probas)**2)
        correct_pred += (predicted_labels == targets).sum()
        
        num_examples += targets.shape[0]
        mse += loss

    mse = mse/i
    acc = correct_pred/num_examples
    return mse, acc

# %%
mse, acc = compute_mse_and_acc(model, X_valid, y_valid)
print(f'Initial valid MSE: {mse:.1f}')
print(f'Initial valid accuracy: {acc*100:.1f}%')
# Out:
# Initial valid MSE: 0.3
# Initial valid accuracy: 9.4%

# %%
def train(model, X_train, y_train, X_valid, y_valid, num_epochs,
          learning_rate=0.1):
    
    epoch_loss = []
    epoch_train_acc = []
    epoch_valid_acc = []
    
    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:
            
            #### Compute outputs ####
            a_h, a_out = model.forward(X_train_mini)

            #### Compute gradients ####
            d_loss__d_w_out, d_loss__d_b_out, d_loss__d_w_h, d_loss__d_b_h = \
                model.backward(X_train_mini, a_h, a_out, y_train_mini)

            #### Update weights ####
            model.weight_h -= learning_rate * d_loss__d_w_h
            model.bias_h -= learning_rate * d_loss__d_b_h
            model.weight_out -= learning_rate * d_loss__d_w_out
            model.bias_out -= learning_rate * d_loss__d_b_out
        
        #### Epoch Logging ####        
        train_mse, train_acc = compute_mse_and_acc(model, X_train, y_train)
        valid_mse, valid_acc = compute_mse_and_acc(model, X_valid, y_valid)
        train_acc, valid_acc = train_acc*100, valid_acc*100
        epoch_train_acc.append(train_acc)
        epoch_valid_acc.append(valid_acc)
        epoch_loss.append(train_mse)
        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train MSE: {train_mse:.2f} '
              f'| Train Acc: {train_acc:.2f}% '
              f'| Valid Acc: {valid_acc:.2f}%')

    return epoch_loss, epoch_train_acc, epoch_valid_acc

# %%
np.random.seed(123) # for the training set shuffling

epoch_loss, epoch_train_acc, epoch_valid_acc = train(
    model, X_train, y_train, X_valid, y_valid,
    num_epochs=500, learning_rate=0.1)
# Out:
# Epoch: 001/500 | Train MSE: 0.00 | Train Acc: 98.12% | Valid Acc: 96.44%
# Epoch: 002/500 | Train MSE: 0.00 | Train Acc: 98.15% | Valid Acc: 96.60%
# Epoch: 003/500 | Train MSE: 0.00 | Train Acc: 98.17% | Valid Acc: 96.42%
# Epoch: 004/500 | Train MSE: 0.00 | Train Acc: 98.13% | Valid Acc: 96.48%
# Epoch: 005/500 | Train MSE: 0.00 | Train Acc: 98.15% | Valid Acc: 96.56%
# Epoch: 006/500 | Train MSE: 0.00 | Train Acc: 98.15% | Valid Acc: 96.26%
# Epoch: 007/500 | Train MSE: 0.00 | Train Acc: 98.19% | Valid Acc: 96.48%
# Epoch: 008/500 | Train MSE: 0.00 | Train Acc: 98.16% | Valid Acc: 96.54%
# Epoch: 009/500 | Train MSE: 0.00 | Train Acc: 98.18% | Valid Acc: 96.58%
# Epoch: 010/500 | Train MSE: 0.00 | Train Acc: 98.18% | Valid Acc: 96.76%
# Epoch: 011/500 | Train MSE: 0.00 | Train Acc: 98.22% | Valid Acc: 96.66%
# Epoch: 012/500 | Train MSE: 0.00 | Train Acc: 98.22% | Valid Acc: 96.66%
# Epoch: 013/500 | Train MSE: 0.00 | Train Acc: 98.21% | Valid Acc: 96.70%
# Epoch: 014/500 | Train MSE: 0.00 | Train Acc: 98.20% | Valid Acc: 96.54%
# Epoch: 015/500 | Train MSE: 0.00 | Train Acc: 98.23% | Valid Acc: 96.52%
# Epoch: 016/500 | Train MSE: 0.00 | Train Acc: 98.23% | Valid Acc: 96.52%
# Epoch: 017/500 | Train MSE: 0.00 | Train Acc: 98.24% | Valid Acc: 96.60%
# Epoch: 018/500 | Train MSE: 0.00 | Train Acc: 98.23% | Valid Acc: 96.74%
# Epoch: 019/500 | Train MSE: 0.00 | Train Acc: 98.26% | Valid Acc: 96.52%
# Epoch: 020/500 | Train MSE: 0.00 | Train Acc: 98.24% | Valid Acc: 96.68%
# Epoch: 021/500 | Train MSE: 0.00 | Train Acc: 98.24% | Valid Acc: 96.64%
# Epoch: 022/500 | Train MSE: 0.00 | Train Acc: 98.26% | Valid Acc: 96.58%
# Epoch: 023/500 | Train MSE: 0.00 | Train Acc: 98.26% | Valid Acc: 96.54%
# Epoch: 024/500 | Train MSE: 0.00 | Train Acc: 98.27% | Valid Acc: 96.60%
# Epoch: 025/500 | Train MSE: 0.00 | Train Acc: 98.28% | Valid Acc: 96.56%
# Epoch: 026/500 | Train MSE: 0.00 | Train Acc: 98.27% | Valid Acc: 96.66%
# Epoch: 027/500 | Train MSE: 0.00 | Train Acc: 98.25% | Valid Acc: 96.42%
# Epoch: 028/500 | Train MSE: 0.00 | Train Acc: 98.29% | Valid Acc: 96.64%
# Epoch: 029/500 | Train MSE: 0.00 | Train Acc: 98.30% | Valid Acc: 96.42%
# Epoch: 030/500 | Train MSE: 0.00 | Train Acc: 98.31% | Valid Acc: 96.56%
# Epoch: 031/500 | Train MSE: 0.00 | Train Acc: 98.31% | Valid Acc: 96.74%
# Epoch: 032/500 | Train MSE: 0.00 | Train Acc: 98.32% | Valid Acc: 96.66%
# Epoch: 033/500 | Train MSE: 0.00 | Train Acc: 98.32% | Valid Acc: 96.46%
# Epoch: 034/500 | Train MSE: 0.00 | Train Acc: 98.32% | Valid Acc: 96.64%
# Epoch: 035/500 | Train MSE: 0.00 | Train Acc: 98.31% | Valid Acc: 96.50%
# Epoch: 036/500 | Train MSE: 0.00 | Train Acc: 98.32% | Valid Acc: 96.58%
# Epoch: 037/500 | Train MSE: 0.00 | Train Acc: 98.32% | Valid Acc: 96.50%
# Epoch: 038/500 | Train MSE: 0.00 | Train Acc: 98.35% | Valid Acc: 96.52%
# Epoch: 039/500 | Train MSE: 0.00 | Train Acc: 98.35% | Valid Acc: 96.66%
# Epoch: 040/500 | Train MSE: 0.00 | Train Acc: 98.34% | Valid Acc: 96.52%
# Epoch: 041/500 | Train MSE: 0.00 | Train Acc: 98.36% | Valid Acc: 96.70%
# Epoch: 042/500 | Train MSE: 0.00 | Train Acc: 98.35% | Valid Acc: 96.52%
# Epoch: 043/500 | Train MSE: 0.00 | Train Acc: 98.37% | Valid Acc: 96.52%
# Epoch: 044/500 | Train MSE: 0.00 | Train Acc: 98.35% | Valid Acc: 96.52%
# Epoch: 045/500 | Train MSE: 0.00 | Train Acc: 98.37% | Valid Acc: 96.64%
# Epoch: 046/500 | Train MSE: 0.00 | Train Acc: 98.39% | Valid Acc: 96.64%
# Epoch: 047/500 | Train MSE: 0.00 | Train Acc: 98.40% | Valid Acc: 96.64%
# Epoch: 048/500 | Train MSE: 0.00 | Train Acc: 98.40% | Valid Acc: 96.58%
# Epoch: 049/500 | Train MSE: 0.00 | Train Acc: 98.40% | Valid Acc: 96.60%
# Epoch: 050/500 | Train MSE: 0.00 | Train Acc: 98.40% | Valid Acc: 96.46%
# Epoch: 051/500 | Train MSE: 0.00 | Train Acc: 98.39% | Valid Acc: 96.66%
# Epoch: 052/500 | Train MSE: 0.00 | Train Acc: 98.38% | Valid Acc: 96.58%
# Epoch: 053/500 | Train MSE: 0.00 | Train Acc: 98.41% | Valid Acc: 96.60%
# Epoch: 054/500 | Train MSE: 0.00 | Train Acc: 98.40% | Valid Acc: 96.58%
# Epoch: 055/500 | Train MSE: 0.00 | Train Acc: 98.40% | Valid Acc: 96.56%
# Epoch: 056/500 | Train MSE: 0.00 | Train Acc: 98.41% | Valid Acc: 96.70%
# Epoch: 057/500 | Train MSE: 0.00 | Train Acc: 98.43% | Valid Acc: 96.58%
# Epoch: 058/500 | Train MSE: 0.00 | Train Acc: 98.45% | Valid Acc: 96.78%
# Epoch: 059/500 | Train MSE: 0.00 | Train Acc: 98.43% | Valid Acc: 96.62%
# Epoch: 060/500 | Train MSE: 0.00 | Train Acc: 98.43% | Valid Acc: 96.50%
# Epoch: 061/500 | Train MSE: 0.00 | Train Acc: 98.43% | Valid Acc: 96.66%
# Epoch: 062/500 | Train MSE: 0.00 | Train Acc: 98.42% | Valid Acc: 96.60%
# Epoch: 063/500 | Train MSE: 0.00 | Train Acc: 98.41% | Valid Acc: 96.54%
# Epoch: 064/500 | Train MSE: 0.00 | Train Acc: 98.43% | Valid Acc: 96.66%
# Epoch: 065/500 | Train MSE: 0.00 | Train Acc: 98.44% | Valid Acc: 96.54%
# Epoch: 066/500 | Train MSE: 0.00 | Train Acc: 98.45% | Valid Acc: 96.66%
# Epoch: 067/500 | Train MSE: 0.00 | Train Acc: 98.45% | Valid Acc: 96.52%
# Epoch: 068/500 | Train MSE: 0.00 | Train Acc: 98.47% | Valid Acc: 96.56%
# Epoch: 069/500 | Train MSE: 0.00 | Train Acc: 98.45% | Valid Acc: 96.66%
# Epoch: 070/500 | Train MSE: 0.00 | Train Acc: 98.49% | Valid Acc: 96.70%
# Epoch: 071/500 | Train MSE: 0.00 | Train Acc: 98.46% | Valid Acc: 96.66%
# Epoch: 072/500 | Train MSE: 0.00 | Train Acc: 98.47% | Valid Acc: 96.52%
# Epoch: 073/500 | Train MSE: 0.00 | Train Acc: 98.48% | Valid Acc: 96.64%
# Epoch: 074/500 | Train MSE: 0.00 | Train Acc: 98.48% | Valid Acc: 96.58%
# Epoch: 075/500 | Train MSE: 0.00 | Train Acc: 98.48% | Valid Acc: 96.58%
# Epoch: 076/500 | Train MSE: 0.00 | Train Acc: 98.49% | Valid Acc: 96.64%
# Epoch: 077/500 | Train MSE: 0.00 | Train Acc: 98.49% | Valid Acc: 96.46%
# Epoch: 078/500 | Train MSE: 0.00 | Train Acc: 98.50% | Valid Acc: 96.44%
# Epoch: 079/500 | Train MSE: 0.00 | Train Acc: 98.49% | Valid Acc: 96.46%
# Epoch: 080/500 | Train MSE: 0.00 | Train Acc: 98.51% | Valid Acc: 96.62%
# Epoch: 081/500 | Train MSE: 0.00 | Train Acc: 98.49% | Valid Acc: 96.48%
# Epoch: 082/500 | Train MSE: 0.00 | Train Acc: 98.47% | Valid Acc: 96.58%
# Epoch: 083/500 | Train MSE: 0.00 | Train Acc: 98.52% | Valid Acc: 96.56%
# Epoch: 084/500 | Train MSE: 0.00 | Train Acc: 98.51% | Valid Acc: 96.42%
# Epoch: 085/500 | Train MSE: 0.00 | Train Acc: 98.53% | Valid Acc: 96.50%
# Epoch: 086/500 | Train MSE: 0.00 | Train Acc: 98.53% | Valid Acc: 96.50%
# Epoch: 087/500 | Train MSE: 0.00 | Train Acc: 98.54% | Valid Acc: 96.60%
# Epoch: 088/500 | Train MSE: 0.00 | Train Acc: 98.53% | Valid Acc: 96.72%
# Epoch: 089/500 | Train MSE: 0.00 | Train Acc: 98.52% | Valid Acc: 96.60%
# Epoch: 090/500 | Train MSE: 0.00 | Train Acc: 98.54% | Valid Acc: 96.54%
# Epoch: 091/500 | Train MSE: 0.00 | Train Acc: 98.52% | Valid Acc: 96.54%
# Epoch: 092/500 | Train MSE: 0.00 | Train Acc: 98.54% | Valid Acc: 96.48%
# Epoch: 093/500 | Train MSE: 0.00 | Train Acc: 98.53% | Valid Acc: 96.50%
# Epoch: 094/500 | Train MSE: 0.00 | Train Acc: 98.53% | Valid Acc: 96.54%
# Epoch: 095/500 | Train MSE: 0.00 | Train Acc: 98.55% | Valid Acc: 96.52%
# Epoch: 096/500 | Train MSE: 0.00 | Train Acc: 98.54% | Valid Acc: 96.56%
# Epoch: 097/500 | Train MSE: 0.00 | Train Acc: 98.56% | Valid Acc: 96.74%
# Epoch: 098/500 | Train MSE: 0.00 | Train Acc: 98.57% | Valid Acc: 96.60%
# Epoch: 099/500 | Train MSE: 0.00 | Train Acc: 98.57% | Valid Acc: 96.58%
# Epoch: 100/500 | Train MSE: 0.00 | Train Acc: 98.57% | Valid Acc: 96.68%
# Epoch: 101/500 | Train MSE: 0.00 | Train Acc: 98.56% | Valid Acc: 96.48%
# Epoch: 102/500 | Train MSE: 0.00 | Train Acc: 98.57% | Valid Acc: 96.68%
# Epoch: 103/500 | Train MSE: 0.00 | Train Acc: 98.57% | Valid Acc: 96.56%
# Epoch: 104/500 | Train MSE: 0.00 | Train Acc: 98.58% | Valid Acc: 96.50%
# Epoch: 105/500 | Train MSE: 0.00 | Train Acc: 98.59% | Valid Acc: 96.46%
# Epoch: 106/500 | Train MSE: 0.00 | Train Acc: 98.59% | Valid Acc: 96.46%
# Epoch: 107/500 | Train MSE: 0.00 | Train Acc: 98.60% | Valid Acc: 96.58%
# Epoch: 108/500 | Train MSE: 0.00 | Train Acc: 98.59% | Valid Acc: 96.56%
# Epoch: 109/500 | Train MSE: 0.00 | Train Acc: 98.58% | Valid Acc: 96.52%
# Epoch: 110/500 | Train MSE: 0.00 | Train Acc: 98.60% | Valid Acc: 96.68%
# Epoch: 111/500 | Train MSE: 0.00 | Train Acc: 98.61% | Valid Acc: 96.62%
# Epoch: 112/500 | Train MSE: 0.00 | Train Acc: 98.59% | Valid Acc: 96.54%
# Epoch: 113/500 | Train MSE: 0.00 | Train Acc: 98.61% | Valid Acc: 96.72%
# Epoch: 114/500 | Train MSE: 0.00 | Train Acc: 98.59% | Valid Acc: 96.42%
# Epoch: 115/500 | Train MSE: 0.00 | Train Acc: 98.61% | Valid Acc: 96.54%
# Epoch: 116/500 | Train MSE: 0.00 | Train Acc: 98.62% | Valid Acc: 96.50%
# Epoch: 117/500 | Train MSE: 0.00 | Train Acc: 98.64% | Valid Acc: 96.48%
# Epoch: 118/500 | Train MSE: 0.00 | Train Acc: 98.61% | Valid Acc: 96.54%
# Epoch: 119/500 | Train MSE: 0.00 | Train Acc: 98.61% | Valid Acc: 96.44%
# Epoch: 120/500 | Train MSE: 0.00 | Train Acc: 98.64% | Valid Acc: 96.52%
# Epoch: 121/500 | Train MSE: 0.00 | Train Acc: 98.63% | Valid Acc: 96.66%
# Epoch: 122/500 | Train MSE: 0.00 | Train Acc: 98.63% | Valid Acc: 96.60%
# Epoch: 123/500 | Train MSE: 0.00 | Train Acc: 98.60% | Valid Acc: 96.62%
# Epoch: 124/500 | Train MSE: 0.00 | Train Acc: 98.62% | Valid Acc: 96.60%
# Epoch: 125/500 | Train MSE: 0.00 | Train Acc: 98.62% | Valid Acc: 96.46%
# Epoch: 126/500 | Train MSE: 0.00 | Train Acc: 98.65% | Valid Acc: 96.42%
# Epoch: 127/500 | Train MSE: 0.00 | Train Acc: 98.62% | Valid Acc: 96.56%
# Epoch: 128/500 | Train MSE: 0.00 | Train Acc: 98.63% | Valid Acc: 96.38%
# Epoch: 129/500 | Train MSE: 0.00 | Train Acc: 98.63% | Valid Acc: 96.58%
# Epoch: 130/500 | Train MSE: 0.00 | Train Acc: 98.65% | Valid Acc: 96.54%
# Epoch: 131/500 | Train MSE: 0.00 | Train Acc: 98.66% | Valid Acc: 96.50%
# Epoch: 132/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.48%
# Epoch: 133/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.52%
# Epoch: 134/500 | Train MSE: 0.00 | Train Acc: 98.66% | Valid Acc: 96.54%
# Epoch: 135/500 | Train MSE: 0.00 | Train Acc: 98.65% | Valid Acc: 96.56%
# Epoch: 136/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.56%
# Epoch: 137/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.56%
# Epoch: 138/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.52%
# Epoch: 139/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.58%
# Epoch: 140/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.62%
# Epoch: 141/500 | Train MSE: 0.00 | Train Acc: 98.68% | Valid Acc: 96.60%
# Epoch: 142/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.54%
# Epoch: 143/500 | Train MSE: 0.00 | Train Acc: 98.69% | Valid Acc: 96.52%
# Epoch: 144/500 | Train MSE: 0.00 | Train Acc: 98.68% | Valid Acc: 96.54%
# Epoch: 145/500 | Train MSE: 0.00 | Train Acc: 98.69% | Valid Acc: 96.70%
# Epoch: 146/500 | Train MSE: 0.00 | Train Acc: 98.69% | Valid Acc: 96.46%
# Epoch: 147/500 | Train MSE: 0.00 | Train Acc: 98.69% | Valid Acc: 96.56%
# Epoch: 148/500 | Train MSE: 0.00 | Train Acc: 98.68% | Valid Acc: 96.46%
# Epoch: 149/500 | Train MSE: 0.00 | Train Acc: 98.67% | Valid Acc: 96.48%
# Epoch: 150/500 | Train MSE: 0.00 | Train Acc: 98.70% | Valid Acc: 96.56%
# Epoch: 151/500 | Train MSE: 0.00 | Train Acc: 98.71% | Valid Acc: 96.62%
# Epoch: 152/500 | Train MSE: 0.00 | Train Acc: 98.71% | Valid Acc: 96.58%
# Epoch: 153/500 | Train MSE: 0.00 | Train Acc: 98.70% | Valid Acc: 96.54%
# Epoch: 154/500 | Train MSE: 0.00 | Train Acc: 98.71% | Valid Acc: 96.58%
# Epoch: 155/500 | Train MSE: 0.00 | Train Acc: 98.72% | Valid Acc: 96.50%
# Epoch: 156/500 | Train MSE: 0.00 | Train Acc: 98.72% | Valid Acc: 96.56%
# Epoch: 157/500 | Train MSE: 0.00 | Train Acc: 98.70% | Valid Acc: 96.54%
# Epoch: 158/500 | Train MSE: 0.00 | Train Acc: 98.71% | Valid Acc: 96.50%
# Epoch: 159/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.54%
# Epoch: 160/500 | Train MSE: 0.00 | Train Acc: 98.71% | Valid Acc: 96.58%
# Epoch: 161/500 | Train MSE: 0.00 | Train Acc: 98.73% | Valid Acc: 96.48%
# Epoch: 162/500 | Train MSE: 0.00 | Train Acc: 98.71% | Valid Acc: 96.46%
# Epoch: 163/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.56%
# Epoch: 164/500 | Train MSE: 0.00 | Train Acc: 98.73% | Valid Acc: 96.48%
# Epoch: 165/500 | Train MSE: 0.00 | Train Acc: 98.76% | Valid Acc: 96.58%
# Epoch: 166/500 | Train MSE: 0.00 | Train Acc: 98.73% | Valid Acc: 96.42%
# Epoch: 167/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.60%
# Epoch: 168/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.62%
# Epoch: 169/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.44%
# Epoch: 170/500 | Train MSE: 0.00 | Train Acc: 98.75% | Valid Acc: 96.58%
# Epoch: 171/500 | Train MSE: 0.00 | Train Acc: 98.75% | Valid Acc: 96.44%
# Epoch: 172/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.50%
# Epoch: 173/500 | Train MSE: 0.00 | Train Acc: 98.75% | Valid Acc: 96.46%
# Epoch: 174/500 | Train MSE: 0.00 | Train Acc: 98.74% | Valid Acc: 96.54%
# Epoch: 175/500 | Train MSE: 0.00 | Train Acc: 98.75% | Valid Acc: 96.48%
# Epoch: 176/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.46%
# Epoch: 177/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.56%
# Epoch: 178/500 | Train MSE: 0.00 | Train Acc: 98.75% | Valid Acc: 96.52%
# Epoch: 179/500 | Train MSE: 0.00 | Train Acc: 98.76% | Valid Acc: 96.44%
# Epoch: 180/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.40%
# Epoch: 181/500 | Train MSE: 0.00 | Train Acc: 98.76% | Valid Acc: 96.50%
# Epoch: 182/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.58%
# Epoch: 183/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.50%
# Epoch: 184/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.50%
# Epoch: 185/500 | Train MSE: 0.00 | Train Acc: 98.78% | Valid Acc: 96.58%
# Epoch: 186/500 | Train MSE: 0.00 | Train Acc: 98.76% | Valid Acc: 96.60%
# Epoch: 187/500 | Train MSE: 0.00 | Train Acc: 98.77% | Valid Acc: 96.56%
# Epoch: 188/500 | Train MSE: 0.00 | Train Acc: 98.78% | Valid Acc: 96.60%
# Epoch: 189/500 | Train MSE: 0.00 | Train Acc: 98.79% | Valid Acc: 96.54%
# Epoch: 190/500 | Train MSE: 0.00 | Train Acc: 98.78% | Valid Acc: 96.46%
# Epoch: 191/500 | Train MSE: 0.00 | Train Acc: 98.78% | Valid Acc: 96.54%
# Epoch: 192/500 | Train MSE: 0.00 | Train Acc: 98.80% | Valid Acc: 96.52%
# Epoch: 193/500 | Train MSE: 0.00 | Train Acc: 98.78% | Valid Acc: 96.50%
# Epoch: 194/500 | Train MSE: 0.00 | Train Acc: 98.80% | Valid Acc: 96.56%
# Epoch: 195/500 | Train MSE: 0.00 | Train Acc: 98.80% | Valid Acc: 96.54%
# Epoch: 196/500 | Train MSE: 0.00 | Train Acc: 98.79% | Valid Acc: 96.58%
# Epoch: 197/500 | Train MSE: 0.00 | Train Acc: 98.80% | Valid Acc: 96.54%
# Epoch: 198/500 | Train MSE: 0.00 | Train Acc: 98.79% | Valid Acc: 96.66%
# Epoch: 199/500 | Train MSE: 0.00 | Train Acc: 98.79% | Valid Acc: 96.50%
# Epoch: 200/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.56%
# Epoch: 201/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.44%
# Epoch: 202/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.48%
# Epoch: 203/500 | Train MSE: 0.00 | Train Acc: 98.82% | Valid Acc: 96.46%
# Epoch: 204/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.48%
# Epoch: 205/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.58%
# Epoch: 206/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.56%
# Epoch: 207/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.44%
# Epoch: 208/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.52%
# Epoch: 209/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.44%
# Epoch: 210/500 | Train MSE: 0.00 | Train Acc: 98.82% | Valid Acc: 96.50%
# Epoch: 211/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.56%
# Epoch: 212/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.64%
# Epoch: 213/500 | Train MSE: 0.00 | Train Acc: 98.81% | Valid Acc: 96.46%
# Epoch: 214/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.42%
# Epoch: 215/500 | Train MSE: 0.00 | Train Acc: 98.82% | Valid Acc: 96.50%
# Epoch: 216/500 | Train MSE: 0.00 | Train Acc: 98.82% | Valid Acc: 96.62%
# Epoch: 217/500 | Train MSE: 0.00 | Train Acc: 98.82% | Valid Acc: 96.64%
# Epoch: 218/500 | Train MSE: 0.00 | Train Acc: 98.82% | Valid Acc: 96.46%
# Epoch: 219/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.62%
# Epoch: 220/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.48%
# Epoch: 221/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.46%
# Epoch: 222/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.58%
# Epoch: 223/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.64%
# Epoch: 224/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.62%
# Epoch: 225/500 | Train MSE: 0.00 | Train Acc: 98.83% | Valid Acc: 96.64%
# Epoch: 226/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.54%
# Epoch: 227/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.56%
# Epoch: 228/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.62%
# Epoch: 229/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.52%
# Epoch: 230/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.58%
# Epoch: 231/500 | Train MSE: 0.00 | Train Acc: 98.85% | Valid Acc: 96.52%
# Epoch: 232/500 | Train MSE: 0.00 | Train Acc: 98.84% | Valid Acc: 96.46%
# Epoch: 233/500 | Train MSE: 0.00 | Train Acc: 98.85% | Valid Acc: 96.56%
# Epoch: 234/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.48%
# Epoch: 235/500 | Train MSE: 0.00 | Train Acc: 98.85% | Valid Acc: 96.36%
# Epoch: 236/500 | Train MSE: 0.00 | Train Acc: 98.85% | Valid Acc: 96.52%
# Epoch: 237/500 | Train MSE: 0.00 | Train Acc: 98.85% | Valid Acc: 96.62%
# Epoch: 238/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.50%
# Epoch: 239/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.56%
# Epoch: 240/500 | Train MSE: 0.00 | Train Acc: 98.85% | Valid Acc: 96.48%
# Epoch: 241/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.48%
# Epoch: 242/500 | Train MSE: 0.00 | Train Acc: 98.87% | Valid Acc: 96.66%
# Epoch: 243/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.42%
# Epoch: 244/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.52%
# Epoch: 245/500 | Train MSE: 0.00 | Train Acc: 98.87% | Valid Acc: 96.40%
# Epoch: 246/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.50%
# Epoch: 247/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.58%
# Epoch: 248/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.42%
# Epoch: 249/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.58%
# Epoch: 250/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.66%
# Epoch: 251/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.52%
# Epoch: 252/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.48%
# Epoch: 253/500 | Train MSE: 0.00 | Train Acc: 98.86% | Valid Acc: 96.42%
# Epoch: 254/500 | Train MSE: 0.00 | Train Acc: 98.87% | Valid Acc: 96.56%
# Epoch: 255/500 | Train MSE: 0.00 | Train Acc: 98.87% | Valid Acc: 96.56%
# Epoch: 256/500 | Train MSE: 0.00 | Train Acc: 98.87% | Valid Acc: 96.42%
# Epoch: 257/500 | Train MSE: 0.00 | Train Acc: 98.87% | Valid Acc: 96.44%
# Epoch: 258/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.56%
# Epoch: 259/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.60%
# Epoch: 260/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.52%
# Epoch: 261/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.58%
# Epoch: 262/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.40%
# Epoch: 263/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.52%
# Epoch: 264/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.62%
# Epoch: 265/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.52%
# Epoch: 266/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.54%
# Epoch: 267/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.54%
# Epoch: 268/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.62%
# Epoch: 269/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.40%
# Epoch: 270/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.46%
# Epoch: 271/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.44%
# Epoch: 272/500 | Train MSE: 0.00 | Train Acc: 98.88% | Valid Acc: 96.50%
# Epoch: 273/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.60%
# Epoch: 274/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.46%
# Epoch: 275/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.52%
# Epoch: 276/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.56%
# Epoch: 277/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.66%
# Epoch: 278/500 | Train MSE: 0.00 | Train Acc: 98.91% | Valid Acc: 96.56%
# Epoch: 279/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.48%
# Epoch: 280/500 | Train MSE: 0.00 | Train Acc: 98.91% | Valid Acc: 96.52%
# Epoch: 281/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.48%
# Epoch: 282/500 | Train MSE: 0.00 | Train Acc: 98.91% | Valid Acc: 96.72%
# Epoch: 283/500 | Train MSE: 0.00 | Train Acc: 98.89% | Valid Acc: 96.52%
# Epoch: 284/500 | Train MSE: 0.00 | Train Acc: 98.91% | Valid Acc: 96.54%
# Epoch: 285/500 | Train MSE: 0.00 | Train Acc: 98.91% | Valid Acc: 96.48%
# Epoch: 286/500 | Train MSE: 0.00 | Train Acc: 98.91% | Valid Acc: 96.60%
# Epoch: 287/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.56%
# Epoch: 288/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.56%
# Epoch: 289/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.50%
# Epoch: 290/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.56%
# Epoch: 291/500 | Train MSE: 0.00 | Train Acc: 98.90% | Valid Acc: 96.50%
# Epoch: 292/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.56%
# Epoch: 293/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.56%
# Epoch: 294/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.54%
# Epoch: 295/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.44%
# Epoch: 296/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.40%
# Epoch: 297/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.52%
# Epoch: 298/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.48%
# Epoch: 299/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.54%
# Epoch: 300/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.52%
# Epoch: 301/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.54%
# Epoch: 302/500 | Train MSE: 0.00 | Train Acc: 98.92% | Valid Acc: 96.52%
# Epoch: 303/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.62%
# Epoch: 304/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.52%
# Epoch: 305/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.52%
# Epoch: 306/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.46%
# Epoch: 307/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.48%
# Epoch: 308/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.70%
# Epoch: 309/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.48%
# Epoch: 310/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.52%
# Epoch: 311/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.66%
# Epoch: 312/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.50%
# Epoch: 313/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.52%
# Epoch: 314/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.52%
# Epoch: 315/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.52%
# Epoch: 316/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.48%
# Epoch: 317/500 | Train MSE: 0.00 | Train Acc: 98.93% | Valid Acc: 96.46%
# Epoch: 318/500 | Train MSE: 0.00 | Train Acc: 98.97% | Valid Acc: 96.58%
# Epoch: 319/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.64%
# Epoch: 320/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.46%
# Epoch: 321/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.58%
# Epoch: 322/500 | Train MSE: 0.00 | Train Acc: 98.94% | Valid Acc: 96.50%
# Epoch: 323/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.58%
# Epoch: 324/500 | Train MSE: 0.00 | Train Acc: 98.96% | Valid Acc: 96.44%
# Epoch: 325/500 | Train MSE: 0.00 | Train Acc: 98.95% | Valid Acc: 96.62%
# Epoch: 326/500 | Train MSE: 0.00 | Train Acc: 98.96% | Valid Acc: 96.56%
# Epoch: 327/500 | Train MSE: 0.00 | Train Acc: 98.96% | Valid Acc: 96.50%
# Epoch: 328/500 | Train MSE: 0.00 | Train Acc: 98.97% | Valid Acc: 96.56%
# Epoch: 329/500 | Train MSE: 0.00 | Train Acc: 98.96% | Valid Acc: 96.56%
# Epoch: 330/500 | Train MSE: 0.00 | Train Acc: 98.97% | Valid Acc: 96.52%
# Epoch: 331/500 | Train MSE: 0.00 | Train Acc: 98.96% | Valid Acc: 96.56%
# Epoch: 332/500 | Train MSE: 0.00 | Train Acc: 98.97% | Valid Acc: 96.54%
# Epoch: 333/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.44%
# Epoch: 334/500 | Train MSE: 0.00 | Train Acc: 98.97% | Valid Acc: 96.54%
# Epoch: 335/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.54%
# Epoch: 336/500 | Train MSE: 0.00 | Train Acc: 98.97% | Valid Acc: 96.52%
# Epoch: 337/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.50%
# Epoch: 338/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.56%
# Epoch: 339/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.44%
# Epoch: 340/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.64%
# Epoch: 341/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.54%
# Epoch: 342/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.48%
# Epoch: 343/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.48%
# Epoch: 344/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.52%
# Epoch: 345/500 | Train MSE: 0.00 | Train Acc: 98.98% | Valid Acc: 96.46%
# Epoch: 346/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.66%
# Epoch: 347/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.56%
# Epoch: 348/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.46%
# Epoch: 349/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.58%
# Epoch: 350/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.62%
# Epoch: 351/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.52%
# Epoch: 352/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.38%
# Epoch: 353/500 | Train MSE: 0.00 | Train Acc: 98.99% | Valid Acc: 96.44%
# Epoch: 354/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.58%
# Epoch: 355/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.54%
# Epoch: 356/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.52%
# Epoch: 357/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.56%
# Epoch: 358/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.50%
# Epoch: 359/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.58%
# Epoch: 360/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.54%
# Epoch: 361/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.50%
# Epoch: 362/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.64%
# Epoch: 363/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.56%
# Epoch: 364/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.60%
# Epoch: 365/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.52%
# Epoch: 366/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.40%
# Epoch: 367/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.58%
# Epoch: 368/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.54%
# Epoch: 369/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.54%
# Epoch: 370/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.52%
# Epoch: 371/500 | Train MSE: 0.00 | Train Acc: 99.00% | Valid Acc: 96.48%
# Epoch: 372/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.58%
# Epoch: 373/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.58%
# Epoch: 374/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.42%
# Epoch: 375/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.44%
# Epoch: 376/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.50%
# Epoch: 377/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.56%
# Epoch: 378/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.50%
# Epoch: 379/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.44%
# Epoch: 380/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.46%
# Epoch: 381/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.54%
# Epoch: 382/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.44%
# Epoch: 383/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.48%
# Epoch: 384/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.38%
# Epoch: 385/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.54%
# Epoch: 386/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.60%
# Epoch: 387/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.50%
# Epoch: 388/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.60%
# Epoch: 389/500 | Train MSE: 0.00 | Train Acc: 99.02% | Valid Acc: 96.60%
# Epoch: 390/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.44%
# Epoch: 391/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.60%
# Epoch: 392/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.54%
# Epoch: 393/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.50%
# Epoch: 394/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.46%
# Epoch: 395/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.52%
# Epoch: 396/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.48%
# Epoch: 397/500 | Train MSE: 0.00 | Train Acc: 99.01% | Valid Acc: 96.42%
# Epoch: 398/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.48%
# Epoch: 399/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.64%
# Epoch: 400/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.60%
# Epoch: 401/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.42%
# Epoch: 402/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.58%
# Epoch: 403/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.40%
# Epoch: 404/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.54%
# Epoch: 405/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.54%
# Epoch: 406/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.46%
# Epoch: 407/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.50%
# Epoch: 408/500 | Train MSE: 0.00 | Train Acc: 99.03% | Valid Acc: 96.42%
# Epoch: 409/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.66%
# Epoch: 410/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.56%
# Epoch: 411/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.46%
# Epoch: 412/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.52%
# Epoch: 413/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.52%
# Epoch: 414/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.52%
# Epoch: 415/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.52%
# Epoch: 416/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.50%
# Epoch: 417/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.42%
# Epoch: 418/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.44%
# Epoch: 419/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.56%
# Epoch: 420/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.50%
# Epoch: 421/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.60%
# Epoch: 422/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.44%
# Epoch: 423/500 | Train MSE: 0.00 | Train Acc: 99.04% | Valid Acc: 96.52%
# Epoch: 424/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.44%
# Epoch: 425/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.54%
# Epoch: 426/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.56%
# Epoch: 427/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.48%
# Epoch: 428/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.56%
# Epoch: 429/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.48%
# Epoch: 430/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.40%
# Epoch: 431/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.58%
# Epoch: 432/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.52%
# Epoch: 433/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.58%
# Epoch: 434/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.58%
# Epoch: 435/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.60%
# Epoch: 436/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.52%
# Epoch: 437/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.54%
# Epoch: 438/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.54%
# Epoch: 439/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.46%
# Epoch: 440/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.52%
# Epoch: 441/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.54%
# Epoch: 442/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.50%
# Epoch: 443/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.46%
# Epoch: 444/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.56%
# Epoch: 445/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.48%
# Epoch: 446/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.44%
# Epoch: 447/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.50%
# Epoch: 448/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.44%
# Epoch: 449/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.52%
# Epoch: 450/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.50%
# Epoch: 451/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.46%
# Epoch: 452/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.44%
# Epoch: 453/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.50%
# Epoch: 454/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.56%
# Epoch: 455/500 | Train MSE: 0.00 | Train Acc: 99.05% | Valid Acc: 96.44%
# Epoch: 456/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.60%
# Epoch: 457/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.54%
# Epoch: 458/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.44%
# Epoch: 459/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.44%
# Epoch: 460/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.48%
# Epoch: 461/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.52%
# Epoch: 462/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.42%
# Epoch: 463/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.62%
# Epoch: 464/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.48%
# Epoch: 465/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.58%
# Epoch: 466/500 | Train MSE: 0.00 | Train Acc: 99.06% | Valid Acc: 96.38%
# Epoch: 467/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.38%
# Epoch: 468/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.56%
# Epoch: 469/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.52%
# Epoch: 470/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.50%
# Epoch: 471/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.56%
# Epoch: 472/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.44%
# Epoch: 473/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.38%
# Epoch: 474/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.44%
# Epoch: 475/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.40%
# Epoch: 476/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.50%
# Epoch: 477/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.52%
# Epoch: 478/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.44%
# Epoch: 479/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.54%
# Epoch: 480/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.54%
# Epoch: 481/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.44%
# Epoch: 482/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.42%
# Epoch: 483/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.52%
# Epoch: 484/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.54%
# Epoch: 485/500 | Train MSE: 0.00 | Train Acc: 99.07% | Valid Acc: 96.46%
# Epoch: 486/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.42%
# Epoch: 487/500 | Train MSE: 0.00 | Train Acc: 99.09% | Valid Acc: 96.46%
# Epoch: 488/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.32%
# Epoch: 489/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.52%
# Epoch: 490/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.46%
# Epoch: 491/500 | Train MSE: 0.00 | Train Acc: 99.09% | Valid Acc: 96.44%
# Epoch: 492/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.54%
# Epoch: 493/500 | Train MSE: 0.00 | Train Acc: 99.09% | Valid Acc: 96.46%
# Epoch: 494/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.50%
# Epoch: 495/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.48%
# Epoch: 496/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.46%
# Epoch: 497/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.46%
# Epoch: 498/500 | Train MSE: 0.00 | Train Acc: 99.08% | Valid Acc: 96.50%
# Epoch: 499/500 | Train MSE: 0.00 | Train Acc: 99.09% | Valid Acc: 96.54%
# Epoch: 500/500 | Train MSE: 0.00 | Train Acc: 99.09% | Valid Acc: 96.48%

# %%
#evaluating neural network performance
plt.plot(range(len(epoch_loss)), epoch_loss)
plt.ylabel('Mean squared error')
plt.xlabel('Epoch')
#plt.savefig('figures/11_07.png', dpi=300)
plt.show()

# %%
plt.plot(range(len(epoch_train_acc)), epoch_train_acc,
         label='Training')
plt.plot(range(len(epoch_valid_acc)), epoch_valid_acc,
         label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='lower right')
#plt.savefig('figures/11_08.png', dpi=300)
plt.show()

# %%
test_mse, test_acc = compute_mse_and_acc(model, X_test, y_test)
print(f'Test accuracy: {test_acc*100:.2f}%')
# Out:
# Test accuracy: 96.31%

# %%
#plot failure cases
X_test_subset = X_test[:1000, :]
y_test_subset = y_test[:1000]

_, probas = model.forward(X_test_subset)
test_pred = np.argmax(probas, axis=1)

misclassified_images = X_test_subset[y_test_subset != test_pred][:25]
misclassified_labels = test_pred[y_test_subset != test_pred][:25]
correct_labels = y_test_subset[y_test_subset != test_pred][:25]

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, 
                       sharex=True, sharey=True, figsize=(8, 8))
ax = ax.flatten()
for i in range(25):
    img = misclassified_images[i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
    ax[i].set_title(f'{i+1}) '
                    f'True: {correct_labels[i]}\n'
                    f' Predicted: {misclassified_labels[i]}')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_09.png', dpi=300)
plt.show()
